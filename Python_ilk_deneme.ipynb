# %%
print("Merhaba","İGÜ")#ilk kod çıktısı
# Out:
# Merhaba İGÜ

# %%
from google.colab import drive  #google colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Python programlama dilinde print komutu ekrandan kullanıcıya bilgi veren koddur.
# Veri Yapılar ve Algoritmalar dersi ilk kodlama çıktısıdır. İGU-İSTKA SİBER AKADEMİ MERKEZİ

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan komut bloğudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd #bize kodun çıktısını dosya yolu olarak veren kod bloğudur
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
